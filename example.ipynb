# %%
run cytometry_processing.py

# %%
df = data_summary([17371, 17373, 17422,17436],ploidy="haploid", only='singlets')

# %%
df
# Out:
#                       atime         conc  events      fl_mean  fl_median  \
# 2015-08-20 09:02:47  25.732    47.723198    1331  6689.009767     6326.0
# 2015-08-20 09:03:37  27.586     3.922612     118  4438.161017     4523.5
# 2015-08-20 09:04:28  27.573     2.493185      75  1171.066667      635.0
# 2015-08-20 09:05:20  27.580     1.495613      45  1345.955556      751.0
# 2015-08-20 09:06:11  27.641     0.264079       8  1444.000000     1167.5
# 2015-08-20 09:07:03  27.569     0.265834       8   803.375000      818.0
# 2015-08-20 09:07:55  24.547    89.518266    2399   626.528970      548.0
# 2015-08-20 09:08:45  24.748    91.679621    2477   594.077917      535.0
# 2015-08-20 15:03:22  11.546    53.700433     669  3152.415546     1289.0
# 2015-08-20 15:03:57  20.142    10.655399     232  4964.267241     5095.0
# 2015-08-20 15:04:41   6.275   159.717106    1084   771.170664      604.0
# 2015-08-20 15:05:11  13.164    47.310027     678  4957.382006     4904.5
# ...

# %%
df_s = df.loc[df["sample_and_treatment"]=="Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1-GEV1 uL of 100 uM b-e"][["conc"]]

# %%
df_s.plot(); plt.show();

# %%
df_s
# Out:
#                             conc      fl_mean
# 2015-08-20 09:07:55    89.518266   626.528970
# 2015-08-20 09:08:45    91.679621   594.077917
# 2015-08-20 15:07:09   266.806323   583.680942
# 2015-08-20 15:07:38    41.312494  2913.714602
# 2015-08-21 09:18:06  5347.031963   329.303160
# 2015-08-21 09:18:32   192.252166  1596.128911
# 2015-08-21 15:33:34   439.129189   530.671885
# 2015-08-21 15:34:01     7.977397  1008.445833

# %%
from ggplot import *

# %%
ggplot(aes(x='conc', y='fl_mean', colour='sample_names_from'), data=df) + geom_point()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-279b8f86282e> in <module>()
# ----> 1 ggplot(aes(x='conc', y='fl_mean', colour='sample_names_from'), data=df) + geom_point()
#
# /Library/Python/2.7/site-packages/ggplot/ggplot.pyc in __init__(self, aesthetics, data)
#      64
#      65         self.aesthetics = aesthetics
# ---> 66         self.data = _apply_transforms(data, self.aesthetics)
#      67
#      68         # defaults
#
# /Library/Python/2.7/site-packages/ggplot/ggplot.pyc in _apply_transforms(data, aes)
#     548             env = EvalEnvironment.capture(eval_env=(aes.__eval_env__ or 1))
#     549             # add factor as a special case
# --> 550             env.add_outer_namespace({"factor":factor})
#     551             try:
#     552                 new_val = env.eval(name, inner_namespace=data)
#
# ...

# %%
meat
# Out:
#           date    beef   veal    pork  lamb_and_mutton  broilers  \
# 0   1944-01-01   751.0   85.0  1280.0             89.0       NaN
# 1   1944-02-01   713.0   77.0  1169.0             72.0       NaN
# 2   1944-03-01   741.0   90.0  1128.0             75.0       NaN
# 3   1944-04-01   650.0   89.0   978.0             66.0       NaN
# 4   1944-05-01   681.0  106.0  1029.0             78.0       NaN
# 5   1944-06-01   658.0  125.0   962.0             79.0       NaN
# 6   1944-07-01   662.0  142.0   796.0             82.0       NaN
# 7   1944-08-01   787.0  175.0   748.0             87.0       NaN
# 8   1944-09-01   774.0  182.0   678.0             91.0       NaN
# 9   1944-10-01   834.0  215.0   777.0            100.0       NaN
# 10  1944-11-01   786.0  197.0   944.0             91.0       NaN
# 11  1944-12-01   764.0  146.0  1013.0             91.0       NaN
# 12  1945-01-01   820.0  119.0  1037.0            100.0       NaN
# ...

# %%
ggplot(aes(x='date', y='beef'), data=meat) + \
    geom_point(color='lightblue') + \
    stat_smooth(span=.15, color='black', se=True) + \
    ggtitle("Beef: It's What's for Dinner") + \
    xlab("Date") + \
    ylab("Head of Cattle Slaughtered")
# Out:
# /Library/Python/2.7/site-packages/matplotlib-1.5.dev1-py2.7-macosx-10.9-intel.egg/matplotlib/__init__.py:866: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <ggplot: (277177181)>

# %%
df['time'] = df.index

# %%
ggplot(aes(x='time', y='fl_mean'), data=df) + geom_point(color='lightblue') +  \
    ggtitle("AlphaFactor Bistable Switch Growth Arrest Test") + \
    xlab("Time") + \
    ylab("Fluoresence") + scale_x_datetime(breaks = date_breaks("1 day"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-bdd4ea80f961> in <module>()
# ----> 1 ggplot(aes(x='time', y='fl_mean'), data=df) + geom_point(color='lightblue') +      ggtitle("AlphaFactor Bistable Switch Growth Arrest Test") +     xlab("Time") +     ylab("Fluoresence") + scale_x_datetime(breaks = date_breaks("1 day"))
#
# NameError: name 'scale_x_datetime' is not defined

# %%
import seaborn as sns

# %%
gammas = sns.load_dataset("gammas")

# %%
gammas
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0             0  IPS        0     0.513433
# 1             0  IPS        1    -0.414368
# 2             0  IPS        2     0.214695
# 3             0  IPS        3     0.814809
# 4             0  IPS        4    -0.894992
# 5             0  IPS        5    -0.073709
# 6             0  IPS        6     3.542734
# 7             0  IPS        7     0.080169
# 8             0  IPS        8     1.547083
# 9             0  IPS        9     2.827153
# 10            0  IPS       10     2.611358
# 11            0  IPS       11    -0.313132
# 12            0  IPS       12     3.773421
# 13            0  IPS       13     4.829915
# 14            0  IPS       14     2.891340
# 15            0  IPS       15    -0.736698
# 16            0  IPS       16     3.316986
# 17            0  IPS       17     3.771426
# 18            0  IPS       18     1.308109
# 19            0  IPS       19    -0.905172
# 20            0   AG        0     1.048369
# ...

# %%
sns.tsplot(data=gammas, time="timepoint", unit="subject",
           condition="ROI", value="BOLD signal"); plt.show();

# %%
plt.show()

# %%
sns.tsplot(data=gammas, time="timepoint", condition="ROI", unit="subject", value="BOLD signal"); plt.show();

# %%
df["sample_and_treatment"] = df["sample_name"].map(str) + df["treatment"]

# %%
df["subject"] = 1

# %%
sns.tsplot(data=df, time="time", unit="subject",
           condition="sample_and_treatment", value="fl_mean"); plt.show();

# %%
df["subject"] = pd.Series([0,0,1,1,2,2,0,0])

# %%
df['subject'] = pd.Series(df.index,[0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-4d36a4f0e5d8> in <module>()
# ----> 1 df['subject'] = pd.Series(df.index,[0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0])
#
# /Library/Python/2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     218                                        raise_cast_failure=True)
#     219
# --> 220                 data = SingleBlockManager(data, index, fastpath=True)
#     221
#     222         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /Library/Python/2.7/site-packages/pandas/core/internals.pyc in __init__(self, block, axis, do_integrity_check, fastpath)
#    3381             block = make_block(block,
#    3382                                placement=slice(0, len(axis)),
# -> 3383                                ndim=1, fastpath=True)
#    3384
# ...

# %%
df['subject'] = pd.Series([0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0], index = df.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-e1416bebbed6> in <module>()
# ----> 1 df['subject'] = pd.Series([0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0], index = df.index)
#
# /Library/Python/2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     218                                        raise_cast_failure=True)
#     219
# --> 220                 data = SingleBlockManager(data, index, fastpath=True)
#     221
#     222         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /Library/Python/2.7/site-packages/pandas/core/internals.pyc in __init__(self, block, axis, do_integrity_check, fastpath)
#    3381             block = make_block(block,
#    3382                                placement=slice(0, len(axis)),
# -> 3383                                ndim=1, fastpath=True)
#    3384
# ...

# %%
df
# Out:
#                       atime         conc  events      fl_mean  fl_median  \
# 2015-08-20 09:02:47  25.732    47.723198    1331  6689.009767     6326.0
# 2015-08-20 09:03:37  27.586     3.922612     118  4438.161017     4523.5
# 2015-08-20 09:04:28  27.573     2.493185      75  1171.066667      635.0
# 2015-08-20 09:05:20  27.580     1.495613      45  1345.955556      751.0
# 2015-08-20 09:06:11  27.641     0.264079       8  1444.000000     1167.5
# 2015-08-20 09:07:03  27.569     0.265834       8   803.375000      818.0
# 2015-08-20 09:07:55  24.547    89.518266    2399   626.528970      548.0
# 2015-08-20 09:08:45  24.748    91.679621    2477   594.077917      535.0
# 2015-08-20 15:03:22  11.546    53.700433     669  3152.415546     1289.0
# 2015-08-20 15:03:57  20.142    10.655399     232  4964.267241     5095.0
# 2015-08-20 15:04:41   6.275   159.717106    1084   771.170664      604.0
# 2015-08-20 15:05:11  13.164    47.310027     678  4957.382006     4904.5
# ...

# %%
df['subject'] = pd.Series([0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0,0,0,1,1,2,2,0,0],index = df.index)

# %%
df["sample_and_treatment"]
# Out:
# 2015-08-20 09:02:47    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:03:37    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:04:28    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:05:20    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:06:11    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:07:03    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 09:07:55                     pGAL1-GAVNY(VP64), pACT1-GEVNone
# 2015-08-20 09:08:45       pGAL1-GAVNY(VP64), pACT1-GEV1 uL of 100 uM b-e
# 2015-08-20 15:03:22    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 15:03:57    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 15:04:41    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 15:05:11    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# 2015-08-20 15:05:47    Tir1_DM, pGAL1-AlphaFactor, pGAL1-GAVNY, pACT1...
# ...

# %%
sns.tsplot(data=df, time="time", unit="subject",
           condition="sample_and_treatment", value="fl_mean"); plt.show();

# %%
df['time'][]
